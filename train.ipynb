# %%
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)

from IPython.display import clear_output
import matplotlib.pyplot as plt

import segmentation_models as sm

import tensorflow_addons as tfa
import cv2
import numpy as np
import matplotlib
from matplotlib import pyplot
from matplotlib.image import imread
# Out:
# 2.2.0

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input Image', 'True Mask', 'Predicted Mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
    plt.axis('off')
  plt.show()

# %%
def create_mask(pred_mask, num=0):
  pred_mask = tf.argmax(pred_mask, axis=-1)
  pred_mask = pred_mask[..., tf.newaxis]
  return pred_mask[num]

def show_predictions(test_mode=False, x=None,y=None, num=1):
  if test_mode:
    print("In testing Mode...")
    for i in range(num):
      pred_mask = model.predict(x, batch_size=1)
      display([x[i], y[i], create_mask(pred_mask, num=i)])

  else:
    display([sample_image, sample_mask,
             create_mask(model.predict(sample_image[tf.newaxis, ...]))])

# %% [markdown]
# Display One sample & get unique colors

# %%
mask = imread('images/train/silver_ng/gt_mask/높음2__분리막 눌림_은색.png') #2048 x 2448
#image = tf.expand_dims(image, -1)
#image = tf.image.grayscale_to_rgb(image)
#mask = tf.image.resize(mask, (480,576))
print(mask.shape)
display([mask])
# Out:
# (2048, 2448, 3)

# %%
colors = np.unique(tf.reshape(mask,[-1,3]), axis=0)

# %%
color_dict = {i: list(x) for i,x in enumerate(colors)}
print(color_dict)

def rgb_to_onehot(rgb_arr, color_dict):
    num_classes = len(color_dict)
    shape = rgb_arr.shape[:2] + (num_classes,)
    arr = np.zeros(shape, dtype=np.int8)
    for i, cls in enumerate(color_dict):
        arr[:, :, i] = np.all(rgb_arr.reshape((-1, 3)) == color_dict[i], axis=1).reshape(shape[:2])
    return arr
# Out:
# {0: [0.0, 0.0, 0.0], 1: [0.9607843, 0.5764706, 0.19215687], 2: [0.98039216, 0.19607843, 0.3254902], 3: [0.98039216, 0.98039216, 0.21568628]}

# %%
a = rgb_to_onehot(mask,color_dict)

bb = tf.expand_dims(np.argmax(a, axis=-1),-1)
bbb = tf.image.resize(bb, (480, 576)) #480, 576 960,1152

#ccc = tf.image.flip_left_right(bbb)
angle = np.random.uniform(0,2*np.pi)

ccc = tfa.image.rotate(bbb, angle)

display([bbb, ccc])

# %% [markdown]
# Preprocess train images/masks:
#   1. resize both
#   2. for x, convert to rgb
#   3. for mask, convert to one hot?
#   4. for both, apply augmentation (optional)
#
#   Note: mask in png format, img in bmp format

# %%
import glob
import cv2
train_x = []
train_y = []

for img in glob.glob("images/train/*/*.bmp"):
    
    #angles to rotate
    angle = np.random.uniform(0,2*np.pi)
    angle2 = np.random.uniform(0,2*np.pi)
    angle3 = np.random.uniform(0,2*np.pi)
    
    #Image
    n = cv2.imread(img)
    n = tf.cast(n, tf.float32) / 255.0
    n = tf.image.resize(n, (480, 576))

    flipped = tfa.image.rotate(n, angle)
    flipped_u = tfa.image.rotate(n, angle2)
    flipped_uu = tfa.image.rotate(n, angle3)
    
    train_x.append(n)
    train_x.append(flipped)
    train_x.append(flipped_u)
    train_x.append(flipped_uu)

    #GET FILE NAME
    dir = "/".join(img.split("/")[:-1]) + "/gt_mask/"
    file_name = img.split("/")[-1].split('.')[0]

    #MASK
    y = imread(dir+file_name+".png")
    #y = tf.cast(y, tf.float32) / 255.0
    a = rgb_to_onehot(y, color_dict) #change to one hot

    bb = tf.expand_dims(np.argmax(a, axis=-1),-1) #combine one hot
    bbb = tf.image.resize(bb, (480, 576))

    flipped2 = tfa.image.rotate(bbb, angle)
    flipped2_u = tfa.image.rotate(bbb, angle2)
    flipped2_uu = tfa.image.rotate(bbb, angle3)

    train_y.append(bbb)
    train_y.append(flipped2)
    train_y.append(flipped2_u)
    train_y.append(flipped2_uu)

train_x = tf.convert_to_tensor(train_x)
train_y = tf.convert_to_tensor(train_y)

print(train_x.shape, np.max(train_x))
print(train_y.shape, np.max(train_y))
# Out:
# (184, 480, 576, 3) 1.0
# (184, 480, 576, 1) 3.0

# %%
display([train_x[13], train_y[13]])

# %%
sample_image = train_x[13]
sample_mask = train_y[13]

# %%
print(train_y.shape)
# 0 shows background, 1 shows "pushed", 2shows "Stamped", 3shows inner circle

sample_weights = np.zeros(train_y.shape)

# your own weight corresponding here:
sample_weights[train_y==0] = 1                                                                                                             
sample_weights[train_y==1] = 10                                                                                                            
sample_weights[train_y==2] = 100                                                                                                             
sample_weights[train_y==3] = 1
# Out:
# (184, 480, 576, 1)

# %% [markdown]
# Define Backbone model as well as segmentation model

# %%
#logits = True/False similar

sm.set_framework('tf.keras')
sm.framework()

ACTIVATION = "softmax"
FROM_LOGITS = False
OPTIMIZER = "RMSprop" #"Adam"
LR = 0.0005

if OPTIMIZER == "Adam":
    opt = keras.optimizers.Adam(learning_rate=LR) #default 0.001
elif OPTIMIZER == "RMSprop":
    opt = keras.optimizers.RMSprop(lr=LR) #default 0.001

BACKBONE = 'inceptionv3'

model = sm.PSPNet(BACKBONE, input_shape=(480, 576, 3), classes=4, encoder_weights='imagenet', activation=ACTIVATION, encoder_freeze = True)

model.compile(
    optimizer = opt,
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=FROM_LOGITS), #loss=sm.losses.bce_jaccard_loss,
    metrics=['accuracy'], #[sm.metrics.iou_score]
)

# %%
show_predictions()

# %%
import gc
import os
import datetime

gc.collect()

#logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
#tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

class DisplayCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    clear_output(wait=True)
    show_predictions()
    print ('{}에포크 이후의 예측 예시'.format(epoch+1))
    print ('Current Accuracy: {}'.format(logs['accuracy']))
    print ('Validation Accuracy: {}'.format(logs['val_accuracy']))
    #tensorboard_callback
    gc.collect()

# %% [markdown]
# Setting validatoin_split causing not to train well for some reason

# %%
EPOCHS = 100

model_history = model.fit(x= train_x,
                          y= train_y, 
                          steps_per_epoch = 30,
                          epochs=EPOCHS,
                          validation_split = 0.1,
                          callbacks=[DisplayCallback()],
                        sample_weight=sample_weights)
# Out:
# 61에포크 이후의 예측 예시
# Current Accuracy: 0.9934577941894531
# Validation Accuracy: 0.987907350063324
# 30/30 [==============================] - 4s 134ms/step - loss: 0.0222 - accuracy: 0.9935 - val_loss: 0.3766 - val_accuracy: 0.9879
# Epoch 62/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9942

# %%
test_x = []
test_y = []

for img in glob.glob("images/test/*.bmp"):
    #angle3 = np.random.uniform(0,2*np.pi)

    n = cv2.imread(img)
    n = tf.cast(n, tf.float32) / 255.0
    n = tf.image.resize(n, (480, 576))
    
    #flipped3 = tfa.image.rotate(n, angle3)
    
    test_x.append(n)
    #test_x.append(flipped3)
    

    dir = "/".join(img.split("/")[:-1]) + "/gt_mask/"
    file_name = img.split("/")[-1].split('.')[0]

    #MASK
    y = imread(dir+file_name+".png")
    #y = tf.cast(y, tf.float32) / 255.0
    a = rgb_to_onehot(y, color_dict) #change to one hot

    bb = tf.expand_dims(np.argmax(a, axis=-1),-1) #combine one hot
    bbb = tf.image.resize(bb, (480, 576))
    #flipped3_u = tfa.image.rotate(bbb, angle3)
    
    test_y.append(bbb)
    #test_y.append(flipped3_u)


test_x = tf.convert_to_tensor(test_x)
test_y = tf.convert_to_tensor(test_y)

print(test_x.shape)
print(test_y.shape)
# Out:
# (4, 480, 576, 3)
# (4, 480, 576, 1)

# %%
show_predictions(test_mode=True, x=test_x, y=test_y, num=4)
# Out:
# In testing Mode...

# %% [markdown]
# Finetuning with smaller learning rate (make whole model trainable)

# %%
model.trainable = True

if OPTIMIZER == "Adam":
    opt = keras.optimizers.Adam(learning_rate=LR/5) #default 0.001
elif OPTIMIZER == "RMSprop":
    opt = keras.optimizers.RMSprop(lr=LR/5) #default 0.001

model.compile(
    optimizer = opt,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=FROM_LOGITS), 
    metrics=[sm.metrics.iou_score],#'accuracy'],
)

# %%
F_EPOCHS = 40
finetune_history = model.fit(x= train_x,
                          y= train_y, 
                          steps_per_epoch = 30,
                          epochs=F_EPOCHS,
                          validation_split = 0.1,
                          callbacks=[DisplayCallback()],
                            sample_weight=sample_weights)
# Out:
# 38에포크 이후의 예측 예시
# 10/30 [=========>....................] - 2s 221ms/step - loss: 0.0134 - iou_score: 0.7034 - val_loss: 0.4128 - val_iou_score: 0.6717

# %%
"""
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
"""
# Out:
# "\n%tensorflow_version 2.x\nimport tensorflow as tf\ndevice_name = tf.test.gpu_device_name()\nif device_name != '/device:GPU:0':\n  raise SystemError('GPU device not found')\nprint('Found GPU at: {}'.format(device_name))\n"

# %% [markdown]
# WITH FINETUNING

# %%
show_predictions(test_mode=True, x=test_x, y=test_y, num=4)
# Out:
# In testing Mode...

# %%
pred_mask = model.predict(test_x, batch_size=1)
aaa = create_mask(pred_mask, num=3)
dd = tf.one_hot(aaa, 4)
print(dd.shape)
# Out:
# (480, 576, 1, 4)

# %%
display([test_y[3], dd[:,:,:,3], dd[:,:,:,1]]) 
# 0 shows background, 1 shows "pushed", 2shows "Stamped", 3shows inner circle

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']


epochs = range(EPOCHS-6)

plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
loss = finetune_history.history['loss']
val_loss = finetune_history.history['val_loss']


epochs = range(F_EPOCHS-2)

plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0.3, 0.8])
plt.legend()
plt.show()

# %%
acc = model_history.history['iou_score']
val_acc = model_history.history['val_iou_score']

epochs = range(EPOCHS-6)

plt.figure()
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5,0.8])
plt.legend()
plt.show()

# %%
acc = finetune_history.history['iou_score']
val_acc = finetune_history.history['val_iou_score']

epochs = range(F_EPOCHS-2)

plt.figure()
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.65,0.75])
plt.legend()
plt.show()

# %%
print("Training accuracy at the last epoch is:", np.round(model_history.history['accuracy'][-1],3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-7ae1a05ee4ef> in <module>
# ----> 1 print("Training accuracy at the last epoch is:", np.round(model_history.history['accuracy'][-1],3))
#
# KeyError: 'accuracy'

# %%
print("Training accuracy (after finetuning) at the last epoch is:", np.round(finetune_history.history['accuracy'][-1],3))
# Out:
# Training accuracy (after finetuning) at the last epoch is: 0.996

# %% [markdown]
# Saving Model for use in Inference

# %%
model.save('saved_model_1005_{}_{}_{}_{}_{}_with_classweights'.format(ACTIVATION, OPTIMIZER, EPOCHS, F_EPOCHS, LR))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: saved_model_1005_softmax_RMSprop_100_40_0.0005_with_classweights/assets
